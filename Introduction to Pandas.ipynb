# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series  = 1 - dimensional

# %%
colours = pd.Series(["Red","Blue","White"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Dataframe = 2-dimensional
car_data = pd.DataFrame({"Car make" : series, "Colour": colours})

# %%
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import data...
dataset = pd.read_csv('D:\datasets\car data.csv')

# %%
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Exporting a dataframe...

dataset.to_csv("exported-dataset.csv", index = False)

# %%
exported_dataset_variable = pd.read_csv("exported-dataset.csv")
exported_dataset_variable
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
## Describe data

# %%
# Attribute..so dont have bracket at the end..
dataset.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
dataset.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=301, step=1)

# %%
dataset.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
# Car_Name         301 non-null object
# Year             301 non-null int64
# Selling_Price    301 non-null float64
# Present_Price    301 non-null float64
# Kms_Driven       301 non-null int64
# Fuel_Type        301 non-null object
# Seller_Type      301 non-null object
# Transmission     301 non-null object
# Owner            301 non-null int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
dataset.mean()
# Out:
# Year              2013.627907
# Selling_Price        4.661296
# Present_Price        7.628472
# Kms_Driven       36947.205980
# Owner                0.043189
# dtype: float64

# %%
data = pd.Series([100,200,300,400])
data.mean()
# Out:
# 250.0

# %%
dataset.sum()
# Out:
# Car_Name         ritzsx4ciazwagon rswiftvitara brezzaciazs cros...
# Year                                                        606102
# Selling_Price                                              1403.05
# Present_Price                                              2296.17
# Kms_Driven                                                11121109
# Fuel_Type        PetrolDieselPetrolPetrolDieselDieselPetrolDies...
# Seller_Type      DealerDealerDealerDealerDealerDealerDealerDeal...
# Transmission     ManualManualManualManualManualManualManualManu...
# Owner                                                           13
# dtype: object

# %%
dataset["Present_Price"].sum()
# Out:
# 2296.17

# %%
len(dataset)
# Out:
# 301

# %%
## Viewing and Selecting data

# %%
dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
dataset.head(7)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0

# %%
dataset.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
# .loc & .iloc

animals = pd.Series(["cat","dog","panda","snake"])
animals
# Out:
# 0      cat
# 1      dog
# 2    panda
# 3    snake
# dtype: object

# %%
animals = pd.Series(["cat","dog","bird","panda","snake"],index=[0,3,9,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
dataset.loc[3]
# Out:
# Car_Name         wagon r
# Year                2011
# Selling_Price       2.85
# Present_Price       4.15
# Kms_Driven          5200
# Fuel_Type         Petrol
# Seller_Type       Dealer
# Transmission      Manual
# Owner                  0
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc

animals.iloc[3]
# Out:
# 'panda'

# %%
dataset.iloc[3]
# Out:
# Car_Name         wagon r
# Year                2011
# Selling_Price       2.85
# Present_Price       4.15
# Kms_Driven          5200
# Fuel_Type         Petrol
# Seller_Type       Dealer
# Transmission      Manual
# Owner                  0
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
dataset.iloc[:3]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
dataset.loc[:3]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0

# %%
dataset["Car_Name"]
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
dataset.Car_Name
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
dataset[dataset["Car_Name"] == "ciaz"]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2      ciaz  2017           7.25           9.85        6900    Petrol
# 6      ciaz  2015           6.75           8.12       18796    Petrol
# 8      ciaz  2016           8.75           8.89       20273    Diesel
# 9      ciaz  2015           7.45           8.92       42367    Diesel
# 11     ciaz  2015           6.85          10.38       51000    Diesel
# 12     ciaz  2015           7.50           9.94       15000    Petrol
# 29     ciaz  2015           7.45          10.38       45000    Diesel
# 45     ciaz  2014           7.50          12.04       15000    Petrol
# 49     ciaz  2017           7.75           9.29       37000    Petrol
#
#    Seller_Type Transmission  Owner
# 2       Dealer       Manual      0
# 6       Dealer       Manual      0
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0
# 11      Dealer       Manual      0
# 12      Dealer    Automatic      0
# ...

# %%
dataset[dataset["Kms_Driven"] < 7000]
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 2                         ciaz  2017           7.25          9.850
# 3                      wagon r  2011           2.85          4.150
# 5                vitara brezza  2018           9.25          9.830
# 10                    alto 800  2017           2.85          3.600
# 21                       ignis  2017           4.90          5.710
# 64                    fortuner  2017          33.00         36.230
# 100  Royal Enfield Thunder 500  2016           1.75          1.900
# 101         UM Renegade Mojave  2017           1.70          1.820
# 102                  KTM RC200  2017           1.65          1.780
# 103          Bajaj Dominar 400  2017           1.45          1.600
# 104  Royal Enfield Classic 350  2017           1.35          1.470
# 110                  KTM RC200  2016           1.20          1.780
# 119  Royal Enfield Thunder 500  2013           1.05          1.900
# ...

# %%
# Crosstab..
pd.crosstab(dataset["Car_Name"],dataset["Fuel_Type"])
# Out:
# Fuel_Type          CNG  Diesel  Petrol
# Car_Name
# 800                  0       0       1
# Activa 3g            0       0       2
# Activa 4g            0       0       1
# Bajaj  ct 100        0       0       1
# Bajaj Avenger 150    0       0       1
# ...                ...     ...     ...
# sx4                  1       1       4
# verna                0       6       8
# vitara brezza        0       1       0
# wagon r              1       0       3
# xcent                0       0       3
#
# [98 rows x 3 columns]

# %%
# Groupby

dataset.groupby(["Car_Name"]).mean()
# Out:
#                           Year  Selling_Price  Present_Price     Kms_Driven  \
# Car_Name
# 800                2003.000000       0.350000       2.280000  127000.000000
# Activa 3g          2012.000000       0.310000       0.530000  250250.000000
# Activa 4g          2017.000000       0.400000       0.510000    1300.000000
# Bajaj  ct 100      2015.000000       0.180000       0.320000   35000.000000
# Bajaj Avenger 150  2016.000000       0.750000       0.800000    7000.000000
# ...                        ...            ...            ...            ...
# sx4                2009.333333       3.158333       8.066667   50740.000000
# verna              2013.571429       6.107857       9.400000   42747.285714
# vitara brezza      2018.000000       9.250000       9.830000    2071.000000
# wagon r            2011.250000       2.512500       4.450000   40644.750000
# xcent              2015.333333       4.966667       7.130000   27448.333333
#
#                       Owner
# Car_Name
# ...

# %%
# %matplotlib inline

# %%
dataset["Selling_Price"].plot()

# %%
dataset["Kms_Driven"].plot()

# %%
dataset["Kms_Driven"].hist()

# %%
dataset["Selling_Price"].hist()

# %%
dataset.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
## manipulatiing Data....

# %%
dataset["Car_Name"].str.lower()
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
dataset["Kms_Driven"] = dataset["Kms_Driven"].fillna(dataset["Kms_Driven"].mean(),inplace = True)

# %%
dataset.dropna()
# Out:
# Empty DataFrame
# Columns: [Car_Name, Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner]
# Index: []

# %%
# Column from series...

Avg_column = pd.Series([20,20,30,25,17])
dataset["Avg"] = Avg_column

# %%
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       None    Petrol
# 1        sx4  2013           4.75           9.54       None    Diesel
# 2       ciaz  2017           7.25           9.85       None    Petrol
# 3    wagon r  2011           2.85           4.15       None    Petrol
# 4      swift  2014           4.60           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60       None    Diesel
# 297     brio  2015           4.00           5.90       None    Petrol
# 298     city  2009           3.35          11.00       None    Petrol
# 299     city  2017          11.50          12.50       None    Diesel
# 300     brio  2016           5.30           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner   Avg
# 0        Dealer       Manual      0  20.0
# ...

# %%
dataset["Avg"].fillna(5,inplace = True)

# %%
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       None    Petrol
# 1        sx4  2013           4.75           9.54       None    Diesel
# 2       ciaz  2017           7.25           9.85       None    Petrol
# 3    wagon r  2011           2.85           4.15       None    Petrol
# 4      swift  2014           4.60           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60       None    Diesel
# 297     brio  2015           4.00           5.90       None    Petrol
# 298     city  2009           3.35          11.00       None    Petrol
# 299     city  2017          11.50          12.50       None    Diesel
# 300     brio  2016           5.30           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner   Avg
# 0        Dealer       Manual      0  20.0
# ...

# %%
# column from python list,,,

Number_Seats = [3,5,6,3,4]
dataset["Number of Seats"] = Number_Seats

dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-d303bc37d4a0> in <module>
#       2
#       3 Number_Seats = [3,5,6,3,4]
# ----> 4 dataset["Number of Seats"] = Number_Seats
#       5
#       6 dataset
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
# ...

# %%
dataset["Percentage"] = [dataset["Present_Price"] - dataset["Selling_Price"]]/dataset["Selling_Price"] * 100

# %%
# createing a column wiht single valuee.

dataset["Road Saftey"] = True
dataset.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven        object
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# Avg              float64
# Road Saftey         bool
# dtype: object

# %%
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       None    Petrol
# 1        sx4  2013           4.75           9.54       None    Diesel
# 2       ciaz  2017           7.25           9.85       None    Petrol
# 3    wagon r  2011           2.85           4.15       None    Petrol
# 4      swift  2014           4.60           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60       None    Diesel
# 297     brio  2015           4.00           5.90       None    Petrol
# 298     city  2009           3.35          11.00       None    Petrol
# 299     city  2017          11.50          12.50       None    Diesel
# 300     brio  2016           5.30           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner   Avg  Road Saftey
# 0        Dealer       Manual      0  20.0         True
# ...

# %%
dataset.drop("Avg", axis=1)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       None    Petrol
# 1        sx4  2013           4.75           9.54       None    Diesel
# 2       ciaz  2017           7.25           9.85       None    Petrol
# 3    wagon r  2011           2.85           4.15       None    Petrol
# 4      swift  2014           4.60           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60       None    Diesel
# 297     brio  2015           4.00           5.90       None    Petrol
# 298     city  2009           3.35          11.00       None    Petrol
# 299     city  2017          11.50          12.50       None    Diesel
# 300     brio  2016           5.30           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner  Road Saftey
# 0        Dealer       Manual      0         True
# ...

# %%
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       None    Petrol
# 1        sx4  2013           4.75           9.54       None    Diesel
# 2       ciaz  2017           7.25           9.85       None    Petrol
# 3    wagon r  2011           2.85           4.15       None    Petrol
# 4      swift  2014           4.60           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60       None    Diesel
# 297     brio  2015           4.00           5.90       None    Petrol
# 298     city  2009           3.35          11.00       None    Petrol
# 299     city  2017          11.50          12.50       None    Diesel
# 300     brio  2016           5.30           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner   Avg  Road Saftey
# 0        Dealer       Manual      0  20.0         True
# ...

# %%
dataset.drop("Avg",axis=1,inplace = True)
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       None    Petrol
# 1        sx4  2013           4.75           9.54       None    Diesel
# 2       ciaz  2017           7.25           9.85       None    Petrol
# 3    wagon r  2011           2.85           4.15       None    Petrol
# 4      swift  2014           4.60           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60       None    Diesel
# 297     brio  2015           4.00           5.90       None    Petrol
# 298     city  2009           3.35          11.00       None    Petrol
# 299     city  2017          11.50          12.50       None    Diesel
# 300     brio  2016           5.30           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner  Road Saftey
# 0        Dealer       Manual      0         True
# ...

# %%
dataset.sample(frac=0.5)
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price Kms_Driven  \
# 272                  city  2015           7.50          10.00       None
# 294                 amaze  2014           3.75           6.80       None
# 87          corolla altis  2012           5.90          13.74       None
# 81               etios gd  2015           4.75           7.85       None
# 140         Honda CBR 150  2013           0.60           1.20       None
# ..                    ...   ...            ...            ...        ...
# 130  Honda CB Hornet 160R  2017           0.75           0.87       None
# 178           TVS Jupyter  2014           0.35           0.52       None
# 203                   i10  2011           2.95           4.60       None
# 64               fortuner  2017          33.00          36.23       None
# 298                  city  2009           3.35          11.00       None
#
#     Fuel_Type Seller_Type Transmission  Owner  Road Saftey
# ...

# %%
dataset_shuffled = dataset.sample(frac=1)

# %%
dataset_shuffled
# Out:
#                Car_Name  Year  Selling_Price  Present_Price Kms_Driven  \
# 155     Honda Activa 4G  2017           0.48           0.51       None
# 259               amaze  2014           3.90           7.00       None
# 293                city  2010           3.25           9.90       None
# 216                 eon  2016           2.90           4.43       None
# 167  TVS Apache RTR 160  2014           0.42           0.81       None
# ..                  ...   ...            ...            ...        ...
# 66               innova  2017          19.75          23.15       None
# 202           grand i10  2015           4.40           5.70       None
# 224               verna  2013           5.11           9.40       None
# 18              wagon r  2015           3.25           5.09       None
# 254                city  2013           5.25           9.90       None
#
#     Fuel_Type Seller_Type Transmission  Owner  Road Saftey
# ...

# %%
##only select 20 precent of the data.
dataset_shuffled.sample(frac=0.2)
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price Kms_Driven  \
# 11                        ciaz  2015           6.85          10.38       None
# 165                  Activa 3g  2016           0.45           0.54       None
# 129          Yamaha FZ S V 2.0  2017           0.78           0.84       None
# 14                       dzire  2009           2.25           7.21       None
# 77                     corolla  2004           1.50          12.35       None
# 163     Bajaj Avenger 220 dtsi  2010           0.45           0.95       None
# 23                    alto k10  2014           2.50           3.46       None
# 114  Royal Enfield Classic 350  2015           1.15           1.47       None
# 43                       dzire  2014           5.50           8.06       None
# 72               corolla altis  2013           7.45          18.61       None
# 101         UM Renegade Mojave  2017           1.70           1.82       None
# ...

# %%
dataset_shuffled.reset_index()
# Out:
#      index            Car_Name  Year  Selling_Price  Present_Price Kms_Driven  \
# 0      155     Honda Activa 4G  2017           0.48           0.51       None
# 1      259               amaze  2014           3.90           7.00       None
# 2      293                city  2010           3.25           9.90       None
# 3      216                 eon  2016           2.90           4.43       None
# 4      167  TVS Apache RTR 160  2014           0.42           0.81       None
# ..     ...                 ...   ...            ...            ...        ...
# 296     66              innova  2017          19.75          23.15       None
# 297    202           grand i10  2015           4.40           5.70       None
# 298    224               verna  2013           5.11           9.40       None
# 299     18             wagon r  2015           3.25           5.09       None
# 300    254                city  2013           5.25           9.90       None
#
# ...

# %%
dataset_shuffled.reset_index(drop = True)
# Out:
#                Car_Name  Year  Selling_Price  Present_Price Kms_Driven  \
# 0       Honda Activa 4G  2017           0.48           0.51       None
# 1                 amaze  2014           3.90           7.00       None
# 2                  city  2010           3.25           9.90       None
# 3                   eon  2016           2.90           4.43       None
# 4    TVS Apache RTR 160  2014           0.42           0.81       None
# ..                  ...   ...            ...            ...        ...
# 296              innova  2017          19.75          23.15       None
# 297           grand i10  2015           4.40           5.70       None
# 298               verna  2013           5.11           9.40       None
# 299             wagon r  2015           3.25           5.09       None
# 300                city  2013           5.25           9.90       None
#
#     Fuel_Type Seller_Type Transmission  Owner  Road Saftey
# ...

# %%
## apply funtion using the lamba variable...Here we are going to change the 
#Selling price of the dataset from Rs into Dollars....
dataset["Selling_Price"] = dataset["Selling_Price"].apply(lambda x: x/70)
dataset
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Kms_Driven Fuel_Type  \
# 0       ritz  2014       0.047857           5.59       None    Petrol
# 1        sx4  2013       0.067857           9.54       None    Diesel
# 2       ciaz  2017       0.103571           9.85       None    Petrol
# 3    wagon r  2011       0.040714           4.15       None    Petrol
# 4      swift  2014       0.065714           6.87       None    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016       0.135714          11.60       None    Diesel
# 297     brio  2015       0.057143           5.90       None    Petrol
# 298     city  2009       0.047857          11.00       None    Petrol
# 299     city  2017       0.164286          12.50       None    Diesel
# 300     brio  2016       0.075714           5.90       None    Petrol
#
#     Seller_Type Transmission  Owner  Road Saftey
# 0        Dealer       Manual      0         True
# ...

# %%
# Try it, run your codee
#Search for it
#Try Again....
